# %% [markdown]
# ### TODO Recording:
#
# - Go to this GitHub page and show what we're using
#
# https://github.com/simplenlg/simplenlg
#
# - Scroll on this page and show
# - Click on the link for "Arria NLG" in the first paragraph of the documentation
# - Scroll on the main Arria page
# - Hover over the "Technology & Products" link on top
# - Click on "Arria for Excel"
#
# - Again hover over the "Technology & Products" link on top
# - Click on "Arria NLG Studio"
#
# - Go to this URL and show
#
# https://pypi.org/project/simplenlg/
#
# - Go to this URL and show the example
#
# https://github.com/Maleehak/SimpleNLG-Tutorial-in-Python/blob/main/NLG.ipynb
#
# - Come to this notebook
#
# - Paste the code cells in line by line for recording

# %% [markdown]
# Installing SimpleNLG library

# %%
# !pip install simplenlg
# Out:
# Collecting simplenlg
#   Downloading simplenlg-0.2.0-py3-none-any.whl (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: simplenlg
# Successfully installed simplenlg-0.2.0

# %% [markdown]
# Importing all required packages

# %%
import simplenlg

from simplenlg.framework import *
from simplenlg.lexicon import *
from simplenlg.realiser.english import *
from simplenlg.phrasespec import *
from simplenlg.features import *

# %% [markdown]
# We are defining lexicon, realiser and nlgFactory

# %%
lexicon = Lexicon.getDefaultLexicon()

realiser = Realiser(lexicon)

nlgFactory = NLGFactory(lexicon)

# %% [markdown]
# Generating  a simple phrase using SimpleNLG

# %%
s1 = nlgFactory.createSentence("budgeting is a fundamental skill for managing personal finances")

s1
# Out:
# {realisation="", category=DocumentCategory.SENTENCE, features={textComponents:[budgeting is a fundamental skill for managing personal finances]}}

# %% [markdown]
# Once you created the sentence, inorder to get the text we need to realise the sentence generated. Note that budgeting has been capitalised and a full stop is added

# %%
output = realiser.realiseSentence(s1)

print(output)
# Out:
# Budgeting is a fundamental skill for managing personal finances.

# %%
p = nlgFactory.createClause()

p.setSubject("She")
p.setVerb("trade")
p.setObject("the stock market")

realiser.realiseSentence(p)
# Out:
# 'She trades the stock market.'

# %%
p = nlgFactory.createClause()

p.setSubject("She")
p.setVerb("trade")
p.setObject("the stock market")

p.setFeature(Feature.NEGATED,True)

realiser.realiseSentence(p)
# Out:
# 'She does not trade the stock market.'

# %%
p = nlgFactory.createClause()

p.setSubject("She")
p.setVerb("trade")
p.setObject("the stock market")

p.setFeature(Feature.INTERROGATIVE_TYPE, InterrogativeType.YES_NO)

realiser.realiseSentence(p)
# Out:
# 'Does She trade the stock market?'

# %%
p = nlgFactory.createClause()

p.setSubject("She")
p.setVerb("trade")
p.setObject("the stock market")

p.setFeature(Feature.INTERROGATIVE_TYPE, InterrogativeType.WHAT_OBJECT)

realiser.realiseSentence(p)
# Out:
# 'What does She trade?'

# %%
subject = nlgFactory.createNounPhrase("John")

obj = nlgFactory.createNounPhrase("a budget")
verb = nlgFactory.createVerbPhrase("create")

subject.addModifier("careful")

p = nlgFactory.createClause()

p.setSubject(subject)
p.setObject(obj)
p.setVerb(verb)

realiser.realiseSentence(p)
# Out:
# 'Careful John creates a budget.'

# %% [markdown]
# Loading a dataset of S&P 500 stocks with its financial informations in  columns.
# https://www.kaggle.com/datasets/paytonfisher/sp-500-companies-with-financial-information?select=financials.csv

# %%
import pandas as pd

stocks_df = pd.read_csv('datasets/financials.csv')

stocks_df.sample(10)
# Out:
#     Symbol                             Name                  Sector    Price  \
# 445    TWX                 Time Warner Inc.  Consumer Discretionary    93.02
# 108    CHD                  Church & Dwight        Consumer Staples    47.38
# 249    IBM  International Business Machines  Information Technology   147.59
# 470    VAR           Varian Medical Systems             Health Care   112.82
# 28    GOOG             Alphabet Inc Class C  Information Technology  1001.52
# 298     MA                  Mastercard Inc.  Information Technology   160.62
# 134    CSX                        CSX Corp.             Industrials    50.47
# 43     APC          Anadarko Petroleum Corp                  Energy    56.20
# 413    SPG         Simon Property Group Inc             Real Estate   152.18
# 354   PAYX                     Paychex Inc.  Information Technology    61.86
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 445           15.35        1.692777            6.62     103.9000
# 108           24.42        1.836605            2.92      54.1799
# 249           10.67        3.899903            6.11     182.7900
# 470           29.93        0.000000            2.69     130.2900
# 28            40.29        0.000000           22.27    1186.8900
# 298           34.99        0.592663            3.65     177.1100
# 134           21.94        1.510289            6.07      60.0400
# 43           -21.29        1.702997           -5.90      70.0000
# 413           13.56        5.036808            6.25     187.3500
# 354           27.49        3.089280            2.26      73.1000
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 445       85.8800  7.418580e+10  7.671000e+09     2.373599        2.73
# 108       43.2100  1.183896e+10  8.680000e+08     3.168245        6.28
# 249      139.1300  1.424330e+11  1.655700e+10     1.817167        7.70
# 470       77.7300  1.069268e+10  5.006000e+08     3.965225        7.32
# 28       803.1903  7.285356e+11  3.271400e+10     6.772653        4.67
# 298      105.8000  1.871020e+11  7.113000e+09    15.020556       26.93
# 134       45.4100  4.734051e+10  5.003000e+09     4.216355        4.27
# 43        39.9600  3.212909e+10  3.115000e+09     3.968221        2.88
# 413      150.1500  4.813984e+10  4.411515e+09     8.754495       13.24
# 354       54.2000  2.325367e+10  1.414900e+09     7.248487       11.77
#
#                                            SEC Filings
# 445  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 108  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 249  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 470  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 28   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 298  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 134  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 43   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 413  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 354  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# Descriptive summary for financials are obtained

# %%
stocks_df.describe()
# Out:
#              Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# count   505.000000      503.000000      505.000000      505.000000
# mean    103.830634       24.808390        1.895953        3.753743
# std     134.427636       41.241081        1.537214        5.689036
# min       2.820000     -251.530000        0.000000      -28.010000
# 25%      46.250000       15.350000        0.794834        1.490000
# 50%      73.920000       19.450000        1.769255        2.890000
# 75%     116.540000       25.750000        2.781114        5.140000
# max    1806.060000      520.150000       12.661196       44.090000
#
#        52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# count   505.000000    505.000000  5.050000e+02  5.050000e+02   505.000000
# mean    122.623832     83.536616  4.923944e+10  3.590328e+09     3.941705
# std     155.362140    105.725473  9.005017e+10  6.840544e+09     3.460110
# min       6.590000      2.800000  2.626102e+09 -5.067000e+09     0.153186
# 25%      56.250000     38.430000  1.273207e+10  7.739320e+08     1.629490
# 50%      86.680000     62.850000  2.140095e+10  1.614399e+09     2.896440
# 75%     140.130000     96.660000  4.511968e+10  3.692749e+09     4.703842
# max    2067.990000   1589.000000  8.095080e+11  7.938600e+10    20.094294
#
#         Price/Book
# count   497.000000
# mean     14.453179
# std      89.660508
# min       0.510000
# 25%       2.020000
# 50%       3.400000
# 75%       6.110000
# max    1403.380000

# %% [markdown]
# We are defining some templates of sentences for getting the data of stock related to Current Market Price,sector,Market cap, dividend yield and also  financial position in respect of its EBITDA.

# %%
def create_descriptions(row):
    subject = nlgFactory.createNounPhrase(
        "The company " + str(row['Name']))

    verb1 = nlgFactory.createVerbPhrase(
        "is part of the " + str(row['Sector']) + " Sector")
    
    object1 = nlgFactory.createNounPhrase(
        " and is currently trading at $" + str(row['Price']) + " per share")
    
    clause1 = nlgFactory.createClause(subject, verb1, object1)
    
    verb2 = nlgFactory.createVerbPhrase("boasts")
    object2 = nlgFactory.createNounPhrase(
        "a market capitalization of " + str(round(row['Market Cap']/1e+9, 2)) + " billion dollars.")
    clause2 = nlgFactory.createClause(
        "the company", verb2, object2)

    object3 = nlgFactory.createNounPhrase(
        " The annual dividend yield for the company is " + str(round(row['Dividend Yield'], 2)))
    
    clause3 = nlgFactory.createClause(object3)   
    
    verb4 = nlgFactory.createVerbPhrase("have")
    object4 = nlgFactory.createNounPhrase(
        "a strong financial position with an EBITDA of " + 
        str(round(row['EBITDA']/1e+9, 2)) + " billion dollars.")
    clause4 = nlgFactory.createClause(
        "It", verb4, object4)
    
    if row['EBITDA'] < 0 :
        # This will negate the sentence
        clause4.setFeature(Feature.NEGATED, True)
        
    s1 = nlgFactory.createSentence(clause1)
    s2 = nlgFactory.createSentence(clause2)
    s3 = nlgFactory.createSentence(clause3)
    s4 = nlgFactory.createSentence(clause4)
    
    paragraph = nlgFactory.createParagraph([s1, s2, s3, s4])
    
    output = realiser.realise(paragraph).getRealisation()                                                                          
    
    return output.strip()

# %% [markdown]
# Creating a new text column for generated paragraphs by applying lambda function

# %%
stocks_df['text'] = stocks_df.apply(lambda r: create_descriptions(r), axis = 1)

stocks_df[['Name', 'Sector', 'Price', 'Dividend Yield', 'Market Cap', 'text']].sample(10)
# Out:
#                            Name                  Sector   Price  \
# 43      Anadarko Petroleum Corp                  Energy   56.20
# 186                 F5 Networks  Information Technology  137.25
# 178       Everest Re Group Ltd.              Financials  241.06
# 6             Acuity Brands Inc             Industrials  145.41
# 338      Norfolk Southern Corp.             Industrials  136.89
# 161            Eastman Chemical               Materials   93.57
# 438        The Cooper Companies             Health Care  223.17
# 20      Alexion Pharmaceuticals             Health Care  108.47
# 230  Hewlett Packard Enterprise  Information Technology   15.04
# 39       AmerisourceBergen Corp             Health Care   91.55
#
#      Dividend Yield    Market Cap  \
# 43         1.702997  3.212909e+10
# 186        0.000000  8.744186e+09
# 178        2.107823  1.013189e+10
# 6          0.351185  6.242378e+09
# 338        2.018503  4.054355e+10
# 161        2.263084  1.422683e+10
# 438        0.026034  1.129796e+10
# 20         0.000000  2.617244e+10
# 230        1.928021  2.480086e+10
# 39         1.613246  2.058770e+10
#
#                                                   text
# 43   The company Anadarko Petroleum Corp is part of...
# 186  The company F5 Networks is part of the Informa...
# 178  The company Everest Re Group Ltd. is part of t...
# 6    The company Acuity Brands Inc is part of the I...
# 338  The company Norfolk Southern Corp. is part of ...
# 161  The company Eastman Chemical is part of the Ma...
# 438  The company The Cooper Companies is part of th...
# 20   The company Alexion Pharmaceuticals is part of...
# 230  The company Hewlett Packard Enterprise is part...
# 39   The company AmerisourceBergen Corp is part of ...

# %% [markdown]
# Checking out financial info of some stocks

# %%
stocks_df.iloc[2, :]
# Out:
# Symbol                                                          ABT
# Name                                            Abbott Laboratories
# Sector                                                  Health Care
# Price                                                         56.27
# Price/Earnings                                                22.51
# Dividend Yield                                             1.908982
# Earnings/Share                                                 0.26
# 52 Week Low                                                    64.6
# 52 Week High                                                  42.28
# Market Cap                                           102121042306.0
# EBITDA                                                 5744000000.0
# Price/Sales                                                 3.74048
# Price/Book                                                     3.19
# SEC Filings       http://www.sec.gov/cgi-bin/browse-edgar?action...
# text              The company Abbott Laboratories is part of the...
# Name: 2, dtype: object

# %% [markdown]
# Checking the generated paragraph for the same stock

# %%
stocks_df['text'][2]
# Out:
# 'The company Abbott Laboratories is part of the Health Care Sector and is currently trading at $56.27 per share. The company boasts a market capitalization of 102.12 billion dollars. The annual dividend yield for the company is 1.91. It has a strong financial position with an EBITDA of 5.74 billion dollars.'

# %%
stocks_df.iloc[10, :]
# Out:
# Symbol                                                          AES
# Name                                                       AES Corp
# Sector                                                    Utilities
# Price                                                         10.06
# Price/Earnings                                                 9.96
# Dividend Yield                                             4.961832
# Earnings/Share                                                -1.72
# 52 Week Low                                                   12.05
# 52 Week High                                                   10.0
# Market Cap                                             6920851212.0
# EBITDA                                                 3001000000.0
# Price/Sales                                                0.659514
# Price/Book                                                      2.2
# SEC Filings       http://www.sec.gov/cgi-bin/browse-edgar?action...
# text              The company AES Corp is part of the Utilities ...
# Name: 10, dtype: object

# %%
stocks_df['text'][10]
# Out:
# 'The company AES Corp is part of the Utilities Sector and is currently trading at $10.06 per share. The company boasts a market capitalization of 6.92 billion dollars. The annual dividend yield for the company is 4.96. It has a strong financial position with an EBITDA of 3.0 billion dollars.'

# %% [markdown]
# Checking stocks with negative EBITDA

# %%
stocks_df[stocks_df['EBITDA'] < 0]
# Out:
#     Symbol              Name                  Sector   Price  Price/Earnings  \
# 23     AGN     Allergan, Plc             Health Care  164.20           10.65
# 59    ADSK      Autodesk Inc  Information Technology  104.81          -77.07
# 143   XRAY   Dentsply Sirona             Health Care   56.85           22.65
# 193     FE  FirstEnergy Corp               Utilities   30.64           11.18
# 209     GE  General Electric             Industrials   14.45           13.76
# 229    HES  Hess Corporation                  Energy   43.00           -9.33
# 245   INCY            Incyte             Health Care   83.92         -119.89
# 299    MAT       Mattel Inc.  Consumer Discretionary   16.00          -14.68
# 336    NBL  Noble Energy Inc                  Energy   25.43          105.96
#
#      Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 23         1.643289           38.35       256.80       160.070  5.666883e+10
# 59         0.000000           -2.61       131.10        81.750  2.434829e+10
# 143        0.600343            1.99        68.98        52.535  1.339051e+10
# 193        4.673807          -14.49        35.22        27.930  1.370608e+10
# 209        3.147541           -0.72        30.59        14.710  1.322493e+11
# 229        2.267060          -19.94        55.48        37.250  1.401613e+10
# 245        0.000000            0.54       153.15        84.210  1.822096e+10
# 299        0.000000           -3.06        26.30        12.710  5.843402e+09
# 336        1.477105           -2.32        39.60        22.985  1.317733e+10
#
#            EBITDA  Price/Sales  Price/Book  \
# 23  -2.888100e+09     4.820115        0.83
# 59  -3.781000e+08    16.506820      224.13
# 143 -4.111000e+08     4.626262        1.80
# 193 -5.067000e+09     1.299448        2.19
# 209 -2.060000e+08     1.088761        1.70
# 229 -8.190000e+08     3.780475        1.08
# 245 -8.168600e+07    17.026990       10.25
# 299 -2.035990e+08     1.186372        3.87
# 336 -5.180000e+08     4.697645        1.44
#
#                                            SEC Filings  \
# 23   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 59   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 143  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 193  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 209  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 229  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 245  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 299  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 336  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
#                                                   text
# 23   The company Allergan, Plc is part of the Healt...
# 59   The company Autodesk Inc is part of the Inform...
# 143  The company Dentsply Sirona is part of the Hea...
# 193  The company FirstEnergy Corp is part of the Ut...
# 209  The company General Electric is part of the In...
# 229  The company Hess Corporation is part of the En...
# 245  The company Incyte is part of the Health Care ...
# 299  The company Mattel Inc. is part of the Consume...
# 336  The company Noble Energy Inc is part of the En...

# %% [markdown]
# Generated sentences for Negative EBITDA companies. Note that financial position for these companies are tagged as not strong.

# %%
stocks_df['text'][23]
# Out:
# 'The company Allergan, Plc is part of the Health Care Sector and is currently trading at $164.2 per share. The company boasts a market capitalization of 56.67 billion dollars. The annual dividend yield for the company is 1.64. It does not have a strong financial position with an EBITDA of -2.89 billion dollars.'

# %%
stocks_df['text'][59]
# Out:
# 'The company Autodesk Inc is part of the Information Technology Sector and is currently trading at $104.81 per share. The company boasts a market capitalization of 24.35 billion dollars. The annual dividend yield for the company is 0.0. It does not have a strong financial position with an EBITDA of -0.38 billion dollars.'
